# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
base=pd.read_csv("C:/Users/Clement/Desktop/Partage_virtual_box/blablacar/dataset/base_from_25-05-2018_to_01-09-2018.csv

# %%
base.head(2)
# Out:
#                                           requete_id      departure_dates  \
# 0  2018-05-25 03:21:17 Bourg-en-Bresse Gap 25/05/...  25/05/2018 05:00:00
# 1  2018-05-25 03:21:17 Bourg-en-Bresse Gap 25/05/...  25/05/2018 05:20:00
#
#   price price_color price_with_commision  seats_left  seats  duration  \
# 0   5 €       BLACK               6,00 €           3      3      3600
# 1   4 €       BLACK               5,00 €           2      4      4200
#
#    distance                             permanent_id departure_city_name  \
# 0        76  1107420526-bourg-en-bresse-villeurbanne     Bourg-en-Bresse
# 1        75  1105561158-bourg-en-bresse-villeurbanne     Bourg-en-Bresse
#
#    departure_latitude  departure_longitude arrival_city_name  \
# 0           46.207878             5.230201      Villeurbanne
# 1           46.205168             5.225501      Villeurbanne
#
#    arrival_latitude  arrival_longitude  \
# 0         45.774069           4.861694
# ...

# %%
base["price"]
base.describe()
base.columns
# base.set_index("") mettre le nom de variables
base.price.head(20)
#base_filtree=base[base.price =="5 €"]
#base.ftypes
#base.info()
#base.describe(include ='all')
base.price.value_counts()
# Out:
# <bound method IndexOpsMixin.value_counts of 0           5 €
# 1           4 €
# 2           5 €
# 3           3 €
# 4           5 €
# 5           6 €
# 6           6 €
# 7           5 €
# 8           6 €
# 9           6 €
# 10          5 €
# 11          5 €
# 12          5 €
# 13          7 €
# 14          5 €
# 15          6 €
# 16          5 €
# 17          5 €
# 18          5 €
# 19          5 €
# 20          5 €
# 21          6 €
# 22          5 €
# 23          5 €
# 24          5 €
# 25          5 €
# 26          4 €
# 27          5 €
# 28          5 €
# 29          5 €
#            ...
# 6813547    46 €
# 6813548    52 €
# 6813549    55 €
# 6813550    50 €
# 6813551    39 €
# 6813552    51 €
# 6813553    55 €
# 6813554    52 €
# 6813555    65 €
# 6813556    53 €
# 6813557    46 €
# 6813558    44 €
# 6813559    51 €
# 6813560    54 €
# 6813561    39 €
# 6813562    51 €
# 6813563    50 €
# 6813564    47 €
# 6813565    39 €
# 6813566    49 €
# 6813567    39 €
# 6813568    39 €
# ...
